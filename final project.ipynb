# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from matplotlib import pyplot as plt

# %%
os.getcwd()
# Out:
# 'C:\\Users\\prajw\\OneDrive\\Desktop\\test jupyter'

# %%
df = pd.read_csv('C:\\Users\\prajw\\Downloads\\SampleDataset12.csv')

# %%
print(df)
# Out:
#      Health Issues  Experience  Salary  Workplace Environment  Discipline
# 0               37          10   26939                     66          41  \
# 1               23          18   37257                     96          50
# 2               40           2   81797                     87          70
# 3               37           2   76162                     61          63
# 4               34          14   61023                     93          83
# ..             ...         ...     ...                    ...         ...
# 995             35           6   70614                     68          53
# 996             32           7   51694                     83          92
# 997             24           4   88420                     66          64
# 998             28           5   95434                     93          80
# 999             34          12   33071                     71          75
#
#      Emp Performance
# 0          27.117655
# 1          37.448983
# 2          81.886481
# 3          76.219129
# 4          61.228171
# ..               ...
# 995        70.677853
# 996        51.916664
# 997        88.427492
# 998        95.495798
# 999        33.313696
#
# [1000 rows x 6 columns]

# %%
df.info
# Out:
# <bound method DataFrame.info of      Health Issues  Experience  Salary  Workplace Environment  Discipline
# 0               37          10   26939                     66          41  \
# 1               23          18   37257                     96          50
# 2               40           2   81797                     87          70
# 3               37           2   76162                     61          63
# 4               34          14   61023                     93          83
# ..             ...         ...     ...                    ...         ...
# 995             35           6   70614                     68          53
# 996             32           7   51694                     83          92
# 997             24           4   88420                     66          64
# 998             28           5   95434                     93          80
# 999             34          12   33071                     71          75
#
#      Emp Performance
# 0          27.117655
# 1          37.448983
# 2          81.886481
# 3          76.219129
# 4          61.228171
# ..               ...
# 995        70.677853
# 996        51.916664
# 997        88.427492
# 998        95.495798
# 999        33.313696
#
# [1000 rows x 6 columns]>

# %%
x=df.iloc[:,:3]
y=df.iloc[:,-1]
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)

# %%
X= df[['Salary']]
Y=df['Emp Performance']

# %%
#LINEAR REGRESSION
mdl = LinearRegression()
mdl.fit(X, Y)
pred = mdl.predict([[75000]])
print("Predicted value (LR): ",pred)
print("Accuracy (LR): ",mdl.score(X[:100], Y[:100])*100)

plt.scatter(X['Salary'], Y, color='b')
plt.plot(X['Salary'], mdl.predict(X),color='black',linewidth=3)
plt.xlabel('Salary')  
plt.ylabel('Emp Performance') 
plt.show()
# Out:
# Predicted value (LR):  [75.09804988]
# Accuracy (LR):  99.99967316128921
# C:\Users\prajw\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
#RANDOM FOREST REGRESSION
from sklearn.ensemble import RandomForestRegressor
mdl = RandomForestRegressor(n_estimators=100,max_depth=6)
mdl.fit(X, Y)
pred = mdl.predict([[80000]])
print("Predicted value (RFR): ",pred[0])
print("Accuracy (RFR): ",mdl.score(X[:100], Y[:100])*100)

plt.scatter(X['Salary'], Y, color='b')
plt.plot(X['Salary'], mdl.predict(X),color='black',linewidth=3)
plt.xlabel('Salary')  
plt.ylabel('Emp Performance') 
plt.show()
# Out:
# C:\Users\prajw\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# Predicted value (RFR):  79.96395492725827
# Accuracy (RFR):  99.9975270926464

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(x_train,y_train)
score=regressor.score(x_train,y_train)
y_predL=regressor.predict(x_test)
y_predL=regressor.predict(x_test)

MAE=mean_absolute_error(y_test,y_predL)
mse=mean_squared_error(y_test,y_predL)
r2=r2_score(y_test,y_predL)
print("MAE",MAE)
print("Mean Square Error of Linear Regression",mse)
print("R2 score of Linear Regression",r2)
# Out:
# MAE 0.03715363528869487
# Mean Square Error of Linear Regression 0.0020540158241927433
# R2 score of Linear Regression 0.9999950718408104

# %%
from sklearn.ensemble import RandomForestRegressor
rf_model=RandomForestRegressor(n_estimators=100, random_state=42)
rf_model.fit(x_train, y_train)
y_pred=rf_model.predict(x_test)

from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
mse=mean_squared_error(y_test,y_pred)
r2=r2_score(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)
print("Mean Square Error of RandomForest Regression",mse)
print("R2 score of RandomForest Regression",r2)
print("Mean absolute Error of RandomForest Regression",mae)
# Out:
# Mean Square Error of RandomForest Regression 0.009893947322373878
# R2 score of RandomForest Regression 0.9999762616495722
# Mean absolute Error of RandomForest Regression 0.07637409248999928
